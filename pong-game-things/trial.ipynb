# %%
import pandas as pd

df = pd.DataFrame({
    "studennt ID": [1,2,3,4],
    "student name": ["joe", "joy", "ben", "guy"],
    "CGPA": [5.0, 4.06, 3.22, 1.50]
})

df.to_csv("Simple student record management system.csv", index=False)
database = pd.read_csv("Simple student record management system.csv")
database
